# %% [markdown]
# # Pick-and-Deliver Traveling Salesman Problem (PD-TSP)
#
# M2 ANDROIDE – Sorbonne Université
# Module MAOA – Projet 2025–2026
# Binôme - Camélia Bouali / Michelle Song
#
# Ce notebook contient les expérimentations pour le problème PD-TSP :
# - heuristiques gloutonnes,
# - méthodes itératives,
# - comparaison linéaire vs quadratique.

# %%
import numpy as np

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %%
import numpy as np
import random
import matplotlib.pyplot as plt
import pandas as pd

random.seed(0)
np.random.seed(0)

# %%
import sys, os
sys.path.append(os.path.join(os.getcwd(), 'sources'))

import model
import importlib
importlib.reload(model)

print(dir(model))  # doit afficher PDInstance et evaluate_solution
# Out:
# ['City', 'PDInstance', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'evaluate_solution', 'math', 'np']

# %%
#Import depuis code source
import sys
import os

# Ajouter le dossier 'sources' au chemin de recherche
sys.path.append(os.path.join(os.getcwd(), 'sources'))
from model import PDInstance, evaluate_solution

# %%
import os
print(os.listdir("sources"))  # vérifie le nom exact du fichier
# Out:
# ['heuristics.py', 'plne.py', 'visualization.py', 'model.py', '__pycache__']

# %%
import importlib
import model
importlib.reload(model)
from model import PDInstance, evaluate_solution

# %% [markdown]
# # Création d’une petite instance test (Code)

# %%
instance = PDInstance.generate_random(n_cities=8)
tour = list(range(instance.n_cities))
pickup_plan = {i: [1]*len(instance.cities[i].pickups) for i in range(instance.n_cities)}

evaluate_solution(instance, tour, pickup_plan)
# Out:
# 53.10911787930438

# %% [markdown]
# ## Visualisation de l’instance

# %% [markdown]
# ## Test de la fonction d'évaluation

# %% [markdown]
# # Heuristiques gloutonnes

# %% [markdown]
# ## Heuristique gloutonne 1
